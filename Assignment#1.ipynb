# %%
import pandas as pd

# %% [markdown]
# ### 1. Read the dataset to python environment.

# %%
data = pd.read_excel(r'C:\Users\sree0\OneDrive\Documents\DSA\iris.xls')

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ### 2. Display the columns in the dataset.

# %%
 data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### 3.  Calculate the mean of each column of the dataset.

# %%
data.mean()
# Out:
# C:\Users\sree0\AppData\Local\Temp\ipykernel_8368\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4. Check for the null values present in the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Bar plot

# %%
sns.barplot(x =data['Classification'],y=data['SL'])
plt.xlabel("Class")
plt.ylabel("Sepal Length (cm)")
plt.title('Sepal Length variation by Class')
plt.show()

# %%
### Scatter Plot

# %%
sns.scatterplot(data=data, x="SL", y="SW", hue="Classification")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Relationship between Sepal Length and Sepal Width")
plt.show()

# %%
### Pair plot

# %%
sns.pairplot(data=data, hue="Classification")
plt.show()

# %%
### Box Plot

# %%
sns.boxplot(data=data, x="Classification", y="PL")
plt.xlabel("Class")
plt.ylabel("Petal Length (cm)")
plt.title("Distribution of Petal Length by Class")
plt.show()

# %%
### Violin Plot

# %%
sns.violinplot(data=data, x="Classification", y="PW")
plt.xlabel("Class")
plt.ylabel("Petal Width (cm)")
plt.title("Distribution of Petal Width by Class")
plt.show()

# %%
### Correlation matrix

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
# Out:
# C:\Users\sree0\AppData\Local\Temp\ipykernel_8368\226542007.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
